# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
diamond = pd.read_csv(r"E:\PROJECT\Diamond\Diamond.csv")

# %%
diamond.head()
# Out:
#     cut color clarity  carat  depth  table  price  x (Premium)  z (Very Good)  \
# 0  Fair     E     VS2   0.22   65.1   61.0    337         3.87           2.49
# 1  Fair     E     SI2   0.86   55.1   69.0   2757         6.45           3.52
# 2  Fair     F     SI2   0.96   66.3   62.0   2759         6.27           4.07
# 3  Fair     F     VS2   0.70   64.5   57.0   2762         5.57           3.58
# 4  Fair     F     VS2   0.70   65.3   55.0   2762         5.63           3.66
#
#    y (Good)
# 0      3.78
# 1      6.33
# 2      5.95
# 3      5.53
# 4      5.58

# %%
diamond.duplicated().sum()
# Out:
# 146

# %%
diamond = diamond.drop_duplicates()

# %%
diamond.duplicated().sum()
# Out:
# 0

# %%
diamond.isnull().sum()
# Out:
# cut              0
# color            0
# clarity          0
# carat            0
# depth            0
# table            0
# price            0
# x (Premium)      0
# z (Very Good)    0
# y (Good)         0
# dtype: int64

# %%
diamond.nunique()
# Out:
# cut                  5
# color                7
# clarity              8
# carat              273
# depth              184
# table              127
# price            11602
# x (Premium)        554
# z (Very Good)      375
# y (Good)           552
# dtype: int64

# %%
diamond.describe()
# Out:
#              carat         depth         table         price   x (Premium)  \
# count  53794.00000  53794.000000  53794.000000  53794.000000  53794.000000
# mean       0.79778     61.748080     57.458109   3933.065082      5.731214
# std        0.47339      1.429909      2.233679   3988.114460      1.120695
# min        0.20000     43.000000     43.000000    326.000000      0.000000
# 25%        0.40000     61.000000     56.000000    951.000000      4.710000
# 50%        0.70000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.04000     62.500000     59.000000   5326.750000      6.540000
# max        5.01000     79.000000     95.000000  18823.000000     10.740000
#
#        z (Very Good)      y (Good)
# count   53794.000000  53794.000000
# mean        3.538714      5.734653
# std         0.705037      1.141209
# min         0.000000      0.000000
# 25%         2.910000      4.720000
# 50%         3.530000      5.710000
# 75%         4.030000      6.540000
# ...

# %%
sns.pairplot(diamond)

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
sns.distplot(diamond['carat'])

plt.subplot(1,2,2)
sns.distplot(diamond['price'])
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.countplot(x=diamond['clarity'])
# Out:
# <Axes: xlabel='clarity', ylabel='count'>

# %%
color= sns.countplot(x=diamond['color'], hue= diamond['color'])

for bars in color.containers:
    color.bar_label(bars)

# %%
diamond.cut.value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>
